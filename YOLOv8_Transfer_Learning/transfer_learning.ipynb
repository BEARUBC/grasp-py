# %%
from ultralytics import YOLO
# Out:
# False

# %% [markdown]
# https://github.com/ultralytics/ultralytics/issues/793
# https://github.com/ultralytics/ultralytics/issues/8485
# https://github.com/orgs/ultralytics/discussions/3862
# https://github.com/ultralytics/ultralytics/issues/189
# https://github.com/orgs/ultralytics/discussions/3862
# https://github.com/ultralytics/ultralytics/issues/3759
#
# https://docs.ultralytics.com/yolov5/tutorials/transfer_learning_with_frozen_layers/#freeze-backbone
# https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/models/v8/yolov8.yaml

# %%
# Load a model
#model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('./model/yolov8n.pt')  # load a pretrained model (recommended for training)

# %%
# Architecture
# https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/models/v8/yolov8.yaml

# Architecture
for i, (name, param) in enumerate(model.named_parameters()):
    print(i, name)
# Out:
# 0 model.model.0.conv.weight
# 1 model.model.0.bn.weight
# 2 model.model.0.bn.bias
# 3 model.model.1.conv.weight
# 4 model.model.1.bn.weight
# 5 model.model.1.bn.bias
# 6 model.model.2.cv1.conv.weight
# 7 model.model.2.cv1.bn.weight
# 8 model.model.2.cv1.bn.bias
# 9 model.model.2.cv2.conv.weight
# 10 model.model.2.cv2.bn.weight
# 11 model.model.2.cv2.bn.bias
# 12 model.model.2.m.0.cv1.conv.weight
# 13 model.model.2.m.0.cv1.bn.weight
# 14 model.model.2.m.0.cv1.bn.bias
# 15 model.model.2.m.0.cv2.conv.weight
# 16 model.model.2.m.0.cv2.bn.weight
# 17 model.model.2.m.0.cv2.bn.bias
# 18 model.model.3.conv.weight
# 19 model.model.3.bn.weight
# 20 model.model.3.bn.bias
# 21 model.model.4.cv1.conv.weight
# 22 model.model.4.cv1.bn.weight
# 23 model.model.4.cv1.bn.bias
# 24 model.model.4.cv2.conv.weight
# 25 model.model.4.cv2.bn.weight
# 26 model.model.4.cv2.bn.bias
# 27 model.model.4.m.0.cv1.conv.weight
# 28 model.model.4.m.0.cv1.bn.weight
# 29 model.model.4.m.0.cv1.bn.bias
# ...

# %%
#
# Freezing Layers (Manually)
#

# no_layers_to_freeze = 10
# for i, (name, param) in enumerate(model.named_parameters()):
#     if i <= no_layers_to_freeze:  # Adjust the number based on the layers you want to freeze
#         param.requires_grad = False

# Doesn't Work
# for name, param in model.named_parameters():
#     if int(name.split('.')[1]) < 20:  # Adjust the condition based on layer naming
#         param.requires_grad = False

# Freeze Layers
# backbone_layers = model.model.backbone.named_parameters()  # Get backbone parameters
# for name, param in backbone_layers:
#     param.requires_grad = False  # Freeze the backbone layers

# %%
# def freeze_layer(trainer):
#     model = trainer.model
#     num_freeze = 10
#     print(f"Freezing {num_freeze} layers")
#     freeze = [f'model.{x}.' for x in range(num_freeze)]  # layers to freeze 
#     for k, v in model.named_parameters(): 
#         v.requires_grad = True  # train all layers 
#         if any(x in k for x in freeze): 
#             print(f'freezing {k}') 
#             v.requires_grad = False 
#     print(f"{num_freeze} layers are freezed.")

# %%
# model = YOLO("yolov8x.pt") 
# model.add_callback("on_train_start", freeze_layer)
# model.train(data="./dataset.yaml")

results = model.train(data='config.yaml', epochs=100, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.1.29 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.20 🚀 Python-3.11.7 torch-2.2.1+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# ...
